# %%
import pandas as pd
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ## Simple regression network

# %% [markdown]
# #### IXI

# %%
df_IXI_simple = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_IXI_simple_02.csv')
df_IXI_simple
# Out:
#      Unnamed: 0  subject  sample  augmentation      label            name  \
# 0             0        0       0             0  68.602325      simple_IXI
# 1             1        1       0             0  31.849419      simple_IXI
# 2             2        2       0             0  67.331963      simple_IXI
# 3             3        3       0             0  23.731691      simple_IXI
# 4             4        4       0             0  29.004791      simple_IXI
# ..          ...      ...     ...           ...        ...             ...
# 295         295       95       0             0  79.000000  simple_ADNI_AD
# 296         296       96       0             0  81.000000  simple_ADNI_AD
# 297         297       97       0             0  75.000000  simple_ADNI_AD
# 298         298       98       0             0  88.000000  simple_ADNI_AD
# 299         299       99       0             0  79.000000  simple_ADNI_AD
#
#      prediction_0
# 0       67.967308
# 1       34.668289
# 2       72.364693
# ...

# %%
df_select = df_IXI_simple[df_IXI_simple['name'].str.match('simple_IXI')]
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
#plt.title('predicted vs. chronological age')
plt.xlabel('chronological age (y)')
plt.ylabel('predicted age (y)')
plt.ylim([10,90])
#plt.show()
matplotlib.rcParams.update({'font.size': 22})
plt.savefig('line_plot.svg')
# Out:
# std 3.714154105298675
# mean 4.754568576812744
# EVALUATION METRICS
# mae 4.754568576812744 rmse 6.021869615189546

# %%
df_select = df_IXI_simple[df_IXI_simple['name'].str.match('simple_IXI')]
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (median)')
plt.show()
# Out:
# EVALUATION METRICS
# mae 4.754568576812744 rmse 6.021869615189546

# %%
df_select = df_IXI_simple[df_IXI_simple['name'].str.match('simple_ADNI_AD')]
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (median)')
plt.show()
# Out:
# std 5.288968246626544
# mean 7.0784166717529295
# EVALUATION METRICS
# mae 7.0784166717529295 rmse 8.820285473930843

# %% [markdown]
# #### ADNI

# %%
df_ADNI_NL_simple = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_ADNI_NL_simple.csv')
df_ADNI_NL_simple
# Out:
#      Unnamed: 0  subject  sample  augmentation      label            name  \
# 0             0        0       0             0  68.602325      simple_IXI
# 1             1        1       0             0  31.849419      simple_IXI
# 2             2        2       0             0  67.331963      simple_IXI
# 3             3        3       0             0  23.731691      simple_IXI
# 4             4        4       0             0  29.004791      simple_IXI
# ..          ...      ...     ...           ...        ...             ...
# 295         295       95       0             0  79.000000  simple_ADNI_AD
# 296         296       96       0             0  81.000000  simple_ADNI_AD
# 297         297       97       0             0  75.000000  simple_ADNI_AD
# 298         298       98       0             0  88.000000  simple_ADNI_AD
# 299         299       99       0             0  79.000000  simple_ADNI_AD
#
#      prediction_0
# 0       74.670349
# 1       69.227348
# 2       77.429733
# ...

# %%
df_select_nl = df_ADNI_NL_simple[df_ADNI_NL_simple['name'].str.match('simple_ADNI_NL')]
df_subj_mean_nl = df_select_nl.groupby('subject').mean()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean_nl['label'], df_subj_mean_nl['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean_nl['label'], df_subj_mean_nl['prediction_0']))
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
print('std', np.abs(df_subj_mean_nl['label']- df_subj_mean_nl['prediction_0']).std())
print('mean', np.abs(df_subj_mean_nl['label']- df_subj_mean_nl['prediction_0']).mean())

plt.scatter(df_subj_mean_nl['label'], df_subj_mean_nl['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (median)')
plt.show()
# Out:
# EVALUATION METRICS
# mae 1.7435687255859376 rmse 2.2003394206050544
# std 1.3489470884739097
# mean 1.7435687255859376

# %%
df_select_ad = df_ADNI_NL_simple[df_ADNI_NL_simple['name'].str.match('simple_ADNI_AD')]
df_subj_mean_ad = df_select_ad.groupby('subject').mean()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean_ad['label'], df_subj_mean_ad['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean_ad['label'], df_subj_mean_ad['prediction_0']))
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
print('std', np.abs(df_subj_mean_ad['label']- df_subj_mean_ad['prediction_0']).std())
print('mean', np.abs(df_subj_mean_ad['label']- df_subj_mean_ad['prediction_0']).mean())

plt.scatter(df_subj_mean_ad['label'], df_subj_mean_ad['prediction_0'], c='blue')
plt.scatter(df_subj_mean_nl['label'], df_subj_mean_nl['prediction_0'], c='orange')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (median)')

# Age difference 
print('mean difference:', (df_subj_mean_ad['prediction_0'] - df_subj_mean_ad['label']).mean())
print('mean std:', (df_subj_mean_ad['prediction_0'] - df_subj_mean_ad['label']).std())
# Out:
# EVALUATION METRICS
# mae 5.343133773803711 rmse 6.8651393809886665
# std 4.33229127279817
# mean 5.343133773803711
# mean difference: 2.6299820709228516
# mean std: 6.373345142868623

# %% [markdown]
# ## Quantile regression

# %%
df_IXI_quantile = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_IXI_new_quantile_01.csv')
df_IXI_quantile
# Out:
#        Unnamed: 0  subject  sample  augmentation      label  \
# 0               0        0       0             0  68.602325
# 1               1        1       0             0  31.849419
# 2               2        2       0             0  67.331963
# 3               3        3       0             0  23.731691
# 4               4        4       0             0  29.004791
# ...           ...      ...     ...           ...        ...
# 15995       15995       99      18             3  67.112938
# 15996       15996       96      19             3  67.455170
# 15997       15997       97      19             3  80.169746
# 15998       15998       98      19             3  53.535934
# 15999       15999       99      19             3  67.112938
#
#                      name  prediction_0  prediction_1  prediction_2
# 0        training_off_IXI     67.647156     65.339127     70.388733
# 1        training_off_IXI     32.668732     30.213520     35.383987
# ...

# %%
df_select = df_IXI_quantile[df_IXI_quantile['name'].str.match('training_off_IXI')]
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())
df_subj_mean_nl
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
# Out:
# std 2.598800570688161
# mean 2.5573573684692366
# EVALUATION METRICS
# mae 2.5573573684692366 rmse 3.636798519606347

# %%
plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (median)')
plt.ylim([10,90])
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_2'] - df_subj_mean['prediction_1'], c='orange')
#plt.title('aleatoric uncertainty (quantile regression)')
plt.xlabel('chronological age (y)')
plt.ylabel('quantile diff. (y)')
plt.xlim([10, 90])
matplotlib.rcParams.update({'font.size': 22})
plt.savefig('quantile_uncertainty.svg') 
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_2'] - df_subj_mean['prediction_0'], c='orange')
plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'] - df_subj_mean['prediction_1'], c='red')
plt.title('aleatoric uncertainty (quantile regression)')
plt.xlabel('chronological age')
plt.ylabel('predicted age (quantile - median)')
plt.xlim([10, 90])
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['label'] - df_subj_mean['prediction_0'], c='red')
plt.title('prediction error vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('prediction error')
plt.xlim([10, 90])
plt.show()

plt.scatter( df_subj_mean['label'] - df_subj_mean['prediction_0'],  df_subj_mean['prediction_2'] - df_subj_mean['prediction_1'], c='red')
plt.title('uncertainty vs. prediction error')
plt.ylabel('predicted age (quantile difference)')
plt.xlabel('prediction error')
plt.show()

#plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_2'])
#plt.errorbar(df_subj_mean['label'],df_subj_mean['prediction_0'],
#             yerr=2*df_subj_std['prediction_0'],
#             fmt='none')

scipy.stats.pearsonr(x, y)[source]

#plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'] - df_subj_mean['prediction_1'])

# %%
# Create plots for latex
labels = df_subj_mean['label']
predictions = df_subj_mean['prediction_0']

print('x y errory')
for k in range(labels.count()):
    print(labels[k], predictions[k], 5.0)
# Out:
# x y errory
# 68.60232543945311 67.64715576171875 5.0
# 31.84941864013672 32.668731689453125 5.0
# 67.33196258544922 68.66775512695311 5.0
# 23.731691360473636 21.503684997558594 5.0
# 29.004791259765625 35.07244110107422 5.0
# 34.28336715698242 33.971935272216804 5.0
# 60.10951232910156 68.28750610351561 5.0
# 38.23408508300781 40.91691207885742 5.0
# 66.90760040283203 65.16349792480469 5.0
# 52.68993759155275 52.23565673828125 5.0
# 52.30116271972656 48.4590072631836 5.0
# 33.349761962890625 33.49910354614258 5.0
# 62.80355834960939 63.87486267089844 5.0
# 75.63312530517578 74.73477172851562 5.0
# 42.50786972045898 44.599998474121094 5.0
# 45.032169342041016 44.50363159179688 5.0
# 39.17590713500977 39.91214370727539 5.0
# 41.88911819458008 39.70448303222656 5.0
# 27.014373779296875 29.65937042236328 5.0
# 68.1341552734375 71.67202758789062 5.0
# 72.306640625 70.71803283691406 5.0
# 65.40999603271484 63.07221221923828 5.0
# 59.78371047973633 59.80888366699219 5.0
# ...

# %% [markdown]
# ## ADNI

# %%
df_ADNI_gaussian = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_ADNI_NL_aleatoric.csv')
df_ADNI_gaussian
# Out:
#      Unnamed: 0  subject  sample  augmentation      label            name  \
# 0             0        0       0             0  68.602325      simple_IXI
# 1             1        1       0             0  31.849419      simple_IXI
# 2             2        2       0             0  67.331963      simple_IXI
# 3             3        3       0             0  23.731691      simple_IXI
# 4             4        4       0             0  29.004791      simple_IXI
# ..          ...      ...     ...           ...        ...             ...
# 295         295       95       0             0  79.000000  simple_ADNI_AD
# 296         296       96       0             0  81.000000  simple_ADNI_AD
# 297         297       97       0             0  75.000000  simple_ADNI_AD
# 298         298       98       0             0  88.000000  simple_ADNI_AD
# 299         299       99       0             0  79.000000  simple_ADNI_AD
#
#      prediction_0  prediction_1
# 0       75.574013      3.555530
# ...

# %%
df_select = df_ADNI_gaussian[df_ADNI_gaussian['name'].str.match('simple_ADNI_NL')]
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std =  df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())

print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
# Out:
# std 1.6771356416835603
# mean 2.1220530700683593
# EVALUATION METRICS
# mae 2.1220530700683593 rmse 2.699586144798092

# %% [markdown]
# ### Gaussian output

# %%
df_IXI_gaussian = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_IXI_aleatoric.csv')
df_IXI_gaussian
# Out:
#      Unnamed: 0  subject  sample  augmentation      label            name  \
# 0             0        0       0             0  68.602325      simple_IXI
# 1             1        1       0             0  31.849419      simple_IXI
# 2             2        2       0             0  67.331963      simple_IXI
# 3             3        3       0             0  23.731691      simple_IXI
# 4             4        4       0             0  29.004791      simple_IXI
# ..          ...      ...     ...           ...        ...             ...
# 295         295       95       0             0  79.000000  simple_ADNI_AD
# 296         296       96       0             0  81.000000  simple_ADNI_AD
# 297         297       97       0             0  75.000000  simple_ADNI_AD
# 298         298       98       0             0  88.000000  simple_ADNI_AD
# 299         299       99       0             0  79.000000  simple_ADNI_AD
#
#      prediction_0  prediction_1
# 0       71.040764      3.662214
# ...

# %%
df_select = df_IXI_gaussian[df_IXI_gaussian['name'].str.match('simple_IXI')]
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std =  df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
# Out:
# std 4.000780467738033
# mean 5.0711599159240714
# EVALUATION METRICS
# mae 5.0711599159240714 rmse 6.446925220630284

# %%
plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (mean)')
plt.xlim([10,90])
plt.show()

plt.scatter(df_subj_mean['label'], np.sqrt(np.exp(df_subj_mean['prediction_1']**2)), c='orange')
#plt.title('predicted vs. chronological age')
plt.xlabel('chronological age (y)')
plt.ylabel('sigma (y)')
plt.xlim([10,90])
matplotlib.rcParams.update({'font.size': 22})
plt.savefig('gaussian_uncertainty.svg')

# %% [markdown]
# ## Bayesian network

# %%
df_IXI_bayesian = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_IXI_bayesian_06.csv')
df_IXI_bayesian
# Out:
#        Unnamed: 0  subject  sample  augmentation      label  \
# 0               0        0       0             0  68.602325
# 1               1        1       0             0  31.849419
# 2               2        2       0             0  67.331963
# 3               3        3       0             0  23.731691
# 4               4        4       0             0  29.004791
# ...           ...      ...     ...           ...        ...
# 19995       19995       99      18             0  79.000000
# 19996       19996       96      19             0  81.000000
# 19997       19997       97      19             0  75.000000
# 19998       19998       98      19             0  88.000000
# 19999       19999       99      19             0  79.000000
#
#                       name  prediction_0
# 0         training_off_IXI     60.354591
# 1         training_off_IXI     32.604595
# 2         training_off_IXI     66.577583
# 3         training_off_IXI     28.179976
# ...

# %%
df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI training_off_ADNI_NL training_off_ADNI_AD
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
mean_std = np.mean(df_subj_std['prediction_0'])

print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())

print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
print(f'average std {mean_std}')


plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (mean)')
plt.xlim([10,90])
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.errorbar(df_subj_mean['label'],df_subj_mean['prediction_0'],
             yerr=2*df_subj_std['prediction_0'],
             fmt='none')
plt.xlabel('chronological age (y)')
plt.ylabel('predicted age (y)')
plt.xlim([10,90])
plt.show()
             
plt.scatter(df_subj_mean['label'], df_subj_std['prediction_0'], c='red', alpha=0.6)
#plt.title('predicted vs. chronological age')
plt.xlabel('chronological age (y)')
plt.ylabel('(std-dev) pred. (y)')
plt.xlim([10,90])
matplotlib.rcParams.update({'font.size': 22})
plt.savefig('epistemic_age.svg')  
plt.show()
# Out:
# std 5.580754901436067
# mean 6.879348543167114
# EVALUATION METRICS
# mae 6.879348543167114 rmse 8.840747332413654
# average std 5.072954280621352

# %%
df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_orig_mean = df_select.groupby('subject').mean()
df_orig_std = df_select.groupby('subject').std()

df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_adni_nl_mean = df_select.groupby('subject').mean()
df_adni_nl_std = df_select.groupby('subject').std()

df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_adni_ad_mean = df_select.groupby('subject').mean()
df_adni_ad_std = df_select.groupby('subject').std()

plt.boxplot([df_orig_std['prediction_0'],
             df_adni_nl_std['prediction_0'],
             df_adni_ad_std['prediction_0']])
plt.ylim([2,12])

print(np.mean(df_orig_std['prediction_0']),
      np.mean(df_adni_nl_std['prediction_0']),
      np.mean(df_adni_ad_std['prediction_0']))
# Out:
# 5.072954280621352 6.330193128129897 6.788292522865971

# %% [markdown]
# ## MC dropout

# %%
df_IXI_drop = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_IXI_mc_dropout_01_b.csv') 
df_IXI_drop
# Out:
#        Unnamed: 0  subject  sample  augmentation      label  \
# 0               0        0       0             0  68.602325
# 1               1        1       0             0  31.849419
# 2               2        2       0             0  67.331963
# 3               3        3       0             0  23.731691
# 4               4        4       0             0  29.004791
# ...           ...      ...     ...           ...        ...
# 19995       19995       99      18             0  79.000000
# 19996       19996       96      19             0  81.000000
# 19997       19997       97      19             0  75.000000
# 19998       19998       98      19             0  88.000000
# 19999       19999       99      19             0  79.000000
#
#                       name  prediction_0
# 0         training_off_IXI     70.239212
# 1         training_off_IXI     42.988937
# 2         training_off_IXI     65.795441
# 3         training_off_IXI     25.827381
# ...

# %%
df_select = df_IXI_drop[df_IXI_drop['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
mean_std = np.mean(df_subj_std['prediction_0'])
print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())

print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
print(f'average std {mean_std}')

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (mean)')
plt.xlim([10,90])
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue', alpha=.4)
plt.errorbar(df_subj_mean['label'],df_subj_mean['prediction_0'],
             yerr=2*df_subj_std['prediction_0'],
             fmt='none', alpha=0.6)
plt.xlabel('chronological age (y)')
plt.ylabel('predicted age (y)')
plt.xlim([10,90])
matplotlib.rcParams.update({'font.size': 22})
plt.savefig('drop_error_bars.svg')  
plt.show()
             
plt.scatter(df_subj_mean['label'], df_subj_std['prediction_0'], c='red')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (std)')
plt.xlim([10,90])
plt.show()

c = df_subj_std['prediction_0']
# Out:
# std 4.786450804224868
# mean 6.246553831100463
# EVALUATION METRICS
# mae 6.246553831100463 rmse 7.854963077767336
# average std 3.951981085517099

# %%
df_select = df_IXI_drop[df_IXI_drop['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_orig_mean = df_select.groupby('subject').mean()
df_drop_orig_std = df_select.groupby('subject').std()

df_select = df_IXI_drop[df_IXI_drop['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_adni_nl_mean = df_select.groupby('subject').mean()
df_drop_adni_nl_std = df_select.groupby('subject').std()

df_select = df_IXI_drop[df_IXI_drop['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_adni_ad_mean = df_select.groupby('subject').mean()
df_drop_adni_ad_std = df_select.groupby('subject').std()

df_select = df_IXI_drop[df_IXI_drop['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_orig_mean = df_select.groupby('subject').mean()
df_drop_orig_std = df_select.groupby('subject').std()

df_select = df_IXI_drop[df_IXI_drop['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_adni_nl_mean = df_select.groupby('subject').mean()
df_drop_adni_nl_std = df_select.groupby('subject').std()

df_select = df_IXI_drop[df_IXI_drop['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_adni_ad_mean = df_select.groupby('subject').mean()
df_drop_adni_ad_std = df_select.groupby('subject').std()


df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_orig_mean = df_select.groupby('subject').mean()
df_bayesian_orig_std = df_select.groupby('subject').std()

df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_adni_nl_mean = df_select.groupby('subject').mean()
df_bayesian_adni_nl_std = df_select.groupby('subject').std()

df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_adni_ad_mean = df_select.groupby('subject').mean()
df_bayesian_adni_ad_std = df_select.groupby('subject').std()

df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_orig_mean = df_select.groupby('subject').mean()
df_bayesian_orig_std = df_select.groupby('subject').std()

df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_adni_nl_mean = df_select.groupby('subject').mean()
df_bayesian_adni_nl_std = df_select.groupby('subject').std()

df_select = df_IXI_bayesian[df_IXI_bayesian['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_adni_ad_mean = df_select.groupby('subject').mean()
df_bayesian_adni_ad_std = df_select.groupby('subject').std()


ax = plt.gca()
bp = ax.boxplot([df_drop_orig_std['prediction_0'],
             df_drop_adni_nl_std['prediction_0'],
             df_drop_adni_ad_std['prediction_0'],
             df_bayesian_orig_std['prediction_0'],
             df_bayesian_adni_nl_std['prediction_0'],
             df_bayesian_adni_ad_std['prediction_0']])
plt.ylim([2,9.5])
i = 0
for median in bp['medians']:
    if i > 2:
        median.set(color='#bb0000', linewidth=2)
    else:
        median.set(color='#0000bb', linewidth=2)
    i = i+1
matplotlib.rcParams.update({'font.size': 22})
plt.savefig('boxplot_drop.svg')  
plt.show()

plt.boxplot([df_drop_orig_mean['prediction_0']-df_orig_mean['label'],
             df_drop_adni_nl_mean['prediction_0']-df_adni_nl_mean['label'],
             df_drop_adni_ad_mean['prediction_0']-df_adni_ad_mean['label']])

plt.show()
orig_mae = mean_absolute_error(df_orig_mean['label'], df_orig_mean['prediction_0'])
adni_nl_mae = mean_absolute_error(df_adni_nl_mean['label'], df_adni_nl_mean['prediction_0'])
adni_ad_mae = mean_absolute_error(df_adni_ad_mean['label'], df_adni_ad_mean['prediction_0'])


print(np.mean(df_drop_orig_std['prediction_0']),
      np.mean(df_drop_adni_nl_std['prediction_0']),
      np.mean(df_drop_adni_ad_std['prediction_0']))
# Out:
# 3.951981085517099 4.561458952535698 4.894073356386582

# %% [markdown]
# ## ADNI bayesian

# %%
df_ADNI_bayesian = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_ADNI_bayesian_03.csv')
df_ADNI_bayesian
# Out:
#       Unnamed: 0  subject  sample  augmentation      label  \
# 0              0        0       0             0  68.602325
# 1              1        1       0             0  31.849419
# 2              2        2       0             0  67.331963
# 3              3        3       0             0  23.731691
# 4              4        4       0             0  29.004791
# ...          ...      ...     ...           ...        ...
# 8195        8195       99      18             0  79.000000
# 8196        8196       96      19             0  81.000000
# 8197        8197       97      19             0  75.000000
# 8198        8198       98      19             0  88.000000
# 8199        8199       99      19             0  79.000000
#
#                      name  prediction_0
# 0        training_off_IXI     79.821808
# 1        training_off_IXI     79.764069
# 2        training_off_IXI     79.697258
# 3        training_off_IXI     79.777428
# 4        training_off_IXI     81.199898
# ...

# %%
df_select = df_ADNI_bayesian[df_ADNI_bayesian['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI training_off_ADNI_NL training_off_ADNI_AD
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))

mean_std = np.mean(df_subj_std['prediction_0'])
mean_std_std = np.std(df_subj_std['prediction_0'])

print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
print(f'average std {mean_std}')
print(f'average std std {mean_std_std}')
df_subj_std

print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (mean)')
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.errorbar(df_subj_mean['label'],df_subj_mean['prediction_0'],
             yerr=2*df_subj_std['prediction_0'],
             fmt='none')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (mean)')
plt.show()
             
plt.scatter(df_subj_mean['label'], df_subj_std['prediction_0'], c='orange')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (std)')
plt.show()
# Out:
# EVALUATION METRICS
# mae 5.673311626434327 rmse 7.064492455544748
# average std 2.0909561103808776
# average std std 0.33182367575170724
# std 4.230790078782092
# mean 5.673311626434327

# %% [markdown]
# ## ADNI drop

# %%
df_ADNI_drop = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/test_ADNI_mc_dropout_02.csv') 
df_ADNI_drop
# Out:
#       Unnamed: 0  subject  sample  augmentation      label  \
# 0              0        0       0             0  68.602325
# 1              1        1       0             0  31.849419
# 2              2        2       0             0  67.331963
# 3              3        3       0             0  23.731691
# 4              4        4       0             0  29.004791
# ...          ...      ...     ...           ...        ...
# 8195        8195       99      18             0  79.000000
# 8196        8196       96      19             0  81.000000
# 8197        8197       97      19             0  75.000000
# 8198        8198       98      19             0  88.000000
# 8199        8199       99      19             0  79.000000
#
#                      name  prediction_0
# 0        training_off_IXI     73.923515
# 1        training_off_IXI     67.367920
# 2        training_off_IXI     77.152748
# 3        training_off_IXI     76.733536
# 4        training_off_IXI     63.950489
# ...

# %%
df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
mean_std = np.mean(df_subj_std['prediction_0'])

print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
print(f'average std {mean_std}')

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (mean)')
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.errorbar(df_subj_mean['label'],df_subj_mean['prediction_0'],
             yerr=df_subj_std['prediction_0'],
             fmt='none')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (mean)')
plt.show()
             
plt.scatter(df_subj_mean['label'], df_subj_std['prediction_0'], c='orange')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (std)')
plt.show()

plt.scatter(df_subj_std['prediction_0'], df_subj_mean['prediction_0'] - df_subj_mean['label'], c='orange')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (std)')
plt.show()
# Out:
# std 5.040450630610168
# mean 6.4049702072143555
# EVALUATION METRICS
# mae 6.4049702072143555 rmse 8.134846310123246
# average std 4.471982116315872

# %%
df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_IXI')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_orig_mean = df_select.groupby('subject').mean()
df_orig_std = df_select.groupby('subject').std()

df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_adni_nl_mean = df_select.groupby('subject').mean()
df_adni_nl_std = df_select.groupby('subject').std()

df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_adni_ad_mean = df_select.groupby('subject').mean()
df_adni_ad_std = df_select.groupby('subject').std()

plt.title('epistemic uncertainty')
plt.boxplot([df_orig_std['prediction_0'],
             df_adni_nl_std['prediction_0'],
             df_adni_ad_std['prediction_0']])

print(np.mean(df_orig_std['prediction_0']),
      np.mean(df_adni_nl_std['prediction_0']),
      np.mean(df_adni_ad_std['prediction_0']))
# Out:
# 4.165926294878953 4.17106430867271 4.471982116315872

# %%
df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_IXI')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_orig_mean = df_select.groupby('subject').mean()
df_drop_orig_std = df_select.groupby('subject').std()

df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_adni_nl_mean = df_select.groupby('subject').mean()
df_drop_adni_nl_std = df_select.groupby('subject').std()

df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_adni_ad_mean = df_select.groupby('subject').mean()
df_drop_adni_ad_std = df_select.groupby('subject').std()

df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_IXI')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_orig_mean = df_select.groupby('subject').mean()
df_drop_orig_std = df_select.groupby('subject').std()

df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_adni_nl_mean = df_select.groupby('subject').mean()
df_drop_adni_nl_std = df_select.groupby('subject').std()

df_select = df_ADNI_drop[df_ADNI_drop['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_drop_adni_ad_mean = df_select.groupby('subject').mean()
df_drop_adni_ad_std = df_select.groupby('subject').std()


df_select = df_ADNI_bayesian[df_ADNI_bayesian['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_orig_mean = df_select.groupby('subject').mean()
df_bayesian_orig_std = df_select.groupby('subject').std()

df_select = df_ADNI_bayesian[df_ADNI_bayesian['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_adni_nl_mean = df_select.groupby('subject').mean()
df_bayesian_adni_nl_std = df_select.groupby('subject').std()

df_select = df_ADNI_bayesian[df_ADNI_bayesian['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_adni_ad_mean = df_select.groupby('subject').mean()
df_bayesian_adni_ad_std = df_select.groupby('subject').std()

df_select = df_ADNI_bayesian[df_ADNI_bayesian['name'].str.match('training_on_orig')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_orig_mean = df_select.groupby('subject').mean()
df_bayesian_orig_std = df_select.groupby('subject').std()

df_select = df_ADNI_bayesian[df_ADNI_bayesian['name'].str.match('training_on_ADNI_NL')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_adni_nl_mean = df_select.groupby('subject').mean()
df_bayesian_adni_nl_std = df_select.groupby('subject').std()

df_select = df_ADNI_bayesian[df_ADNI_bayesian['name'].str.match('training_on_ADNI_AD')] # training_on_random training_on_blurry1 training_off_IXI, training_on_orig
df_bayesian_adni_ad_mean = df_select.groupby('subject').mean()
df_bayesian_adni_ad_std = df_select.groupby('subject').std()


ax = plt.gca()
bp = ax.boxplot([df_drop_adni_nl_std['prediction_0'],
                df_drop_adni_ad_std['prediction_0'],
             2.7*df_bayesian_adni_nl_std['prediction_0'],
             2.7*df_bayesian_adni_ad_std['prediction_0']])
plt.ylim([2,9.5])
i = 0
for median in bp['medians']:
    if i > 1:
        median.set(color='#bb0000', linewidth=2)
    else:
        median.set(color='#0000bb', linewidth=2)
    i = i+1
matplotlib.rcParams.update({'font.size': 22})
plt.savefig('boxplot_drop_2.svg')  
plt.show()

plt.boxplot([df_drop_orig_mean['prediction_0']-df_orig_mean['label'],
             df_drop_adni_nl_mean['prediction_0']-df_adni_nl_mean['label'],
             df_drop_adni_ad_mean['prediction_0']-df_adni_ad_mean['label']])

plt.show()
orig_mae = mean_absolute_error(df_orig_mean['label'], df_orig_mean['prediction_0'])
adni_nl_mae = mean_absolute_error(df_adni_nl_mean['label'], df_adni_nl_mean['prediction_0'])
adni_ad_mae = mean_absolute_error(df_adni_ad_mean['label'], df_adni_ad_mean['prediction_0'])

# %% [markdown]
# ## ADNI ADNL quantiles

# %%
df_ADNIADNL_quantile = pd.read_csv('/home/raheppt1/projects/age_prediction/reports/predictions/ADNI_ADNL_quantile_01.csv')
df_ADNIADNL_quantile
# Out:
#      Unnamed: 0  subject  sample  augmentation      label            name  \
# 0             0        0       0             0  68.602325      simple_IXI
# 1             1        1       0             0  31.849419      simple_IXI
# 2             2        2       0             0  67.331963      simple_IXI
# 3             3        3       0             0  23.731691      simple_IXI
# 4             4        4       0             0  29.004791      simple_IXI
# ..          ...      ...     ...           ...        ...             ...
# 295         295       95       0             0  79.000000  simple_ADNI_AD
# 296         296       96       0             0  81.000000  simple_ADNI_AD
# 297         297       97       0             0  75.000000  simple_ADNI_AD
# 298         298       98       0             0  88.000000  simple_ADNI_AD
# 299         299       99       0             0  79.000000  simple_ADNI_AD
#
#      prediction_0  prediction_1  prediction_2
# ...

# %%
df_select = df_ADNIADNL_quantile[df_ADNIADNL_quantile['name'].str.match('simple_ADNI_NL')]
df_subj_mean = df_select.groupby('subject').mean()
df_subj_std = df_select.groupby('subject').std()

# Mean prediction error
mae = mean_absolute_error(df_subj_mean['label'], df_subj_mean['prediction_0'])
rmse = math.sqrt(mean_squared_error(df_subj_mean['label'], df_subj_mean['prediction_0']))
print('EVALUATION METRICS')
print(f'mae {mae} rmse {rmse}')
print((df_subj_mean['prediction_2'] - df_subj_mean['prediction_1']).mean())
print('std', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).std())
print('mean', np.abs(df_subj_mean['label']- df_subj_mean['prediction_0']).mean())

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'], c='blue')
plt.title('predicted vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('predicted age (median)')
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_2'] - df_subj_mean['prediction_1'], c='orange')
plt.xlabel('chronological age (y)')
plt.ylabel('quantile diff. (y)')
matplotlib.rcParams.update({'font.size': 22})
plt.savefig('adni_quantile.svg')  
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_2'] - df_subj_mean['prediction_0'], c='orange')
plt.scatter(df_subj_mean['label'], df_subj_mean['prediction_0'] - df_subj_mean['prediction_1'], c='red')
plt.title('aleatoric uncertainty (quantile regression)')
plt.xlabel('chronological age')
plt.ylabel('predicted age (quantile - median)')
plt.show()

plt.scatter(df_subj_mean['label'], df_subj_mean['label'] - df_subj_mean['prediction_0'], c='red')
plt.title('prediction error vs. chronological age')
plt.xlabel('chronological age')
plt.ylabel('prediction error')
plt.show()

plt.scatter( df_subj_mean['label'] - df_subj_mean['prediction_0'],  df_subj_mean['prediction_2'] - df_subj_mean['prediction_1'], c='red')
plt.title('uncertainty vs. prediction error')
plt.ylabel('predicted age (quantile difference)')
plt.xlabel('prediction error')
plt.show()
# Out:
# EVALUATION METRICS
# mae 2.158926811218261 rmse 2.6159878444654026
# 8.334137344360352
# std 1.4847464927287746
# mean 2.158926811218261
